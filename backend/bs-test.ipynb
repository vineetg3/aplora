# %%
from bs4 import BeautifulSoup

# %%
pip install html2text
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 3.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for html2text: filename=html2text-2024.2.26-py3-none-any.whl size=33111 sha256=7c294c3f7bee8d4189128a68f8343da15697e58965850d799a3e0f585340f59c
#   Stored in directory: /Users/vineet/Library/Caches/pip/wheels/2b/01/23/578505d65e2a97d78bf1fe3fc8256ecf37572dc1df598b0eaf
# Successfully built html2text
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
#   Obtaining dependency information for requests from https://files.pythonhosted.org/packages/f9/9b/335f9764261e915ed497fcdeb11df5dfd6f7bf257d4a6a2a686d80da4d54/requests-2.32.3-py3-none-any.whl.metadata
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/fa/44/b730e2a2580110ced837ac083d8ad222343c96bb6b66e9e4e706e4d0b6df/charset_normalizer-3.4.0-cp312-cp312-macosx_11_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/76/c6/c88e154df9c4e1a2a66ccf0005a88dfb2650c1dffb6f5ce603dfbd452ce3/idna-3.10-py3-none-any.whl.metadata
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
#   Obtaining dependency information for urllib3<3,>=1.21.1 from https://files.pythonhosted.org/packages/ce/d9/5f4c13cecde62396b0d3fe530a50ccea91e7dfc1ccf0e09c228841bb5ba8/urllib3-2.2.3-py3-none-any.whl.metadata
# ...

# %%
from bs4 import BeautifulSoup

# Sample HTML documents
html1 = '''
<html>
    <body>
        <div class="content">
            <h1>Title</h1>
            <p>This is a paragraph before the target.</p>
        </div>
        <div class="footer">
            <p>Footer content.</p>
        </div>
    </body>
</html>
'''

html2 = '''
<html>
    <body>
        <div class="content">
            <h1>Title</h1>
            <p>This is a paragraph before the target.</p>
        </div>
        <div class="footer">
            <p>Footer content has changed.</p>
        </div>
    </body>
</html>
'''

# Function to extract text from all tags for comparison
def extract_text_from_html(html):
    soup = BeautifulSoup(html, 'html.parser')
    return {tag.name: [element.get_text(strip=True) for element in soup.find_all(tag.name)] for tag in soup.find_all()}

# Extract elements and compare
html1_elements = extract_text_from_html(html1)
html2_elements = extract_text_from_html(html2)

# Compare the elements
differences = {}

# Find differences
for tag in html1_elements:
    if tag not in html2_elements:
        differences[tag] = ("Missing in HTML2", html1_elements[tag])
    elif html1_elements[tag] != html2_elements[tag]:
        differences[tag] = ("Different", html1_elements[tag], html2_elements[tag])

for tag in html2_elements:
    if tag not in html1_elements:
        differences[tag] = ("Missing in HTML1", html2_elements[tag])

# Print the differences
for tag, diff in differences.items():
    print(f"Tag: {tag}")
    if diff[0] == "Different":
        print(f"  Different content: HTML1 -> {diff[1]}, HTML2 -> {diff[2]}")
    else:
        print(f"  {diff[0]}: {diff[1]}")
# Out:
# Tag: html
#   Different content: HTML1 -> ['TitleThis is a paragraph before the target.Footer content.'], HTML2 -> ['TitleThis is a paragraph before the target.Footer content has changed.']
# Tag: body
#   Different content: HTML1 -> ['TitleThis is a paragraph before the target.Footer content.'], HTML2 -> ['TitleThis is a paragraph before the target.Footer content has changed.']
# Tag: div
#   Different content: HTML1 -> ['TitleThis is a paragraph before the target.', 'Footer content.'], HTML2 -> ['TitleThis is a paragraph before the target.', 'Footer content has changed.']
# Tag: p
#   Different content: HTML1 -> ['This is a paragraph before the target.', 'Footer content.'], HTML2 -> ['This is a paragraph before the target.', 'Footer content has changed.']

# %%
from bs4 import BeautifulSoup

# Sample HTML
html_content = """
<html>
    <head><title>Sample HTML</title></head>
    <body>
        <h1>Heading</h1>
        <p>This is a paragraph.</p>
    </body>
</html>
"""

# Parse the HTML
soup = BeautifulSoup(html_content, "html.parser")

# Convert to XML
xml_content = soup.prettify(formatter="xml")

print(xml_content)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 18
#      15 soup = BeautifulSoup(html_content, "html.parser")
#      17 # Convert to XML
# ---> 18 xml_content = soup.prettify(formatter="xml")
#      20 print(xml_content)
#
# File ~/Documents/Tamu/Fall2024/CS689LLMs/project/llmproj/lib/python3.12/site-packages/bs4/element.py:1926, in Tag.prettify(self, encoding, formatter)
#    1916 """Pretty-print this PageElement as a string.
#    1917
#    1918 :param encoding: The eventual encoding of the string. If this is None,
#    (...)
#    1923     (otherwise).
#    1924 """
#    1925 if encoding is None:
# -> 1926     return self.decode(True, formatter=formatter)
#    1927 else:
#    1928     return self.encode(encoding, True, formatter=formatter)
#
# ...

# %%
import requests
import html2text

# URL of the website
url = "https://job-boards.greenhouse.io/figma/jobs/5227935004?gh_jid=5227935004"

# Fetch the HTML content
response = requests.get(url)
html_content = response.text

# Convert HTML to Markdown
converter = html2text.HTML2Text()
converter.ignore_links = False  # Keep hyperlinks in the Markdown
markdown_content = converter.handle(html_content)

print(markdown_content)
# Out:
# [![Figma
# Logo](https://s4-recruiting.cdn.greenhouse.io/external_greenhouse_job_boards/logos/400/377/100/original/Figma-
# icon-sm.png?1726611002)](https://www.figma.com/careers/)
#
# [Back to jobs](https://www.figma.com/careers/)
#
# # Software Engineer - Early Career (2025)
#
# San Francisco, CA • New York, NY • United States
#
# Apply
#
# Figma is growing our team of passionate people on a mission to make design
# accessible to all. [Born on the Web](https://www.figma.com/blog/meet-us-in-
# the-browser/), Figma helps entire product teams
# [brainstorm](https://www.figma.com/blog/introducing-figjam/), design and build
# better products — from start to finish. Whether it’s consolidating tools,
# simplifying workflows, or collaborating across teams and time zones, Figma
# makes the design process faster, more efficient, and fun while keeping
# everyone on the same page. From great products to long-lasting companies, we
# believe that nothing great is made alone—come
# ...

# %% [markdown]
# # Relevant field extraction and type

# %%
from typing import Optional

from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from pydantic import BaseModel, Field

# Define a custom prompt to provide instructions and any additional context.
# 1) You can add examples into the prompt template to improve extraction quality
# 2) Introduce additional parameters to take context into account (e.g., include metadata
#    about the document from which the text was extracted.)
prompt_template = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are an expert extraction algorithm. "
            "Only extract relevant information from the text. "
            "If you do not know the value of an attribute asked to extract, "
            "return null for the attribute's value.",
        ),
        # Please see the how-to about improving performance with
        # reference examples.
        # MessagesPlaceholder('examples'),
        ("human", " Here is the document you need to check relevancy from: {text}"),
        ("human", " Here are the input fields: {input_fields}"),
    ]
)

# %%
from typing import List, Optional, Literal, Dict, Union

from pydantic import BaseModel, Field


class InputTagDescription(BaseModel):
    """Information about an input tag"""

    is_relevant: Literal["yes","no"] = Field(description="If this field is relevant to be filled from the given context. If it has aria-required, it generally is relevant. If input seems like a radio button, check relevant radio buttons and keep only one of them as relevant because we can only select one.")
    input_type: Literal["dropdown", "text", "radiobutton"] = Field(
                description="Should be one of dropdown, text, radiobutton. If it contains aria-haspopup its generally a dropdown."
            )
    key: str = Field(description="unique key that should be picked up from the input tag dictionary")
    text_value: Union[None|str] = Field(description="If you decide that the html tag is of type text, what should be the value that should fill this? Keep it accurate and \
                                                        only get it from the context document.")



class InputTagDescriptionList(BaseModel):
    """Extracted data about input tags and relevancy from the appended document"""

    # Creates a model so that we can extract multiple entities.
    tags: List[InputTagDescription]

# %%
import getpass
import os


from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")

# %%
structured_llm = llm.with_structured_output(schema=InputTagDescriptionList)

# %%
resume = '''
VINEET GANDHAM (He/him)
www.linkedin.com/in/vineetgandham www.github.com/vineetg3 vineet.gandham@tamu.edu (979)-344-3541
EDUCATION
Texas A&M University, College Station, Texas |Master of Computer Science |CGPA: 4.0/4.0 Manipal Institute of Technology, Manipal |B.Tech in Computer Science |CGPA: 9.37/10.0 Dec 2024 or May 2025
July 2022
Courses - Machine Learning |Large Language Models |Deep Learning |Database |Operating Systems |Distributed Processing |
Network Security |Data Structures and Algorithms |Cloud Computing |Software Engineering
SKILLS AND CERTIFICATIONS
Languages Software Frameworks Python, Java, C/C++, SQL, Javascript/HTML/CSS, Ruby, Bash
Spring Boot, ReactJS, Flask, FastAPI, SQLAlchemy, NodeJS, Hibernate, MyBatis, gRPC, Protobufs
MQTT, Kafka, Spark, Zookeeper
Data Science Tools Pytorch, Langchain, Tensorflow,Numpy, Sklearn, Pandas, Matplotlib, Pytorch Geometric, Gephi
Tools Git, Linux, Docker, Kubernetes, Google Cloud(GCP)
Certifications • Google Cloud Engineer
EXPERIENCE
•Texas A&M University, Graduate Research Assistant |Data Science, MLOps, SDE Jan 2024 -
· Spearheading the implementation of a GraphRAG-based LLM for a digital twin product to automate the analysis of documentation
and logs, targeting a 50% reduction in debugging time.
· Developed an MLOps library to automate preprocessing, training, deployment, and serving of ML time series models via MQTT for
1000+ IOT sensors on a local cloud, utilizing real-time data via TDEngine time series database.
· Identified and implemented the most efficient tools (FastAPI, Celery, SQL, Redis, EMQX MQTT broker) for real-time data process-
ing in the MLOps pipeline, optimizing system performance and reducing deployment time by 90% from 8 hours to 30 minutes.
· Experimented with and evaluated Graph Neural Networks (GNN) architectures using PyTorch for a doctor referral recommenda-
tion system, which increased referral accuracy to 84% and significantly improved patient care coordination.
· Resolved inconsistencies in 1 million referral records and 10,000 doctor data entries by scraping and wrangling data with NumPy
and Pandas, leading to improved data accuracy and smoother analytics processes.
· Feature engineered by incorporating diverse data sources, including zip codes, universities, and cities of study. Leveraged a fine-
tuned BERT model to encode and enrich biomedical data, enhancing the model’s ability to capture complex relationships and
patterns.
•Texas Instruments, Software ML Developer |ML, Spring Boot, ReactJS, Kubernetes, SQL July 2022 - July 2023
· Led a cross-functional team of 8 in the migration of a ML inference cloud platform, resulting in $55K annual cost savings by
transitioning from third-party services to in-house solutions in less than 3 months.
· Developed Node.js server to manage power control for TI evaluation boards and data routing; configured Bash scripts and Docker
containers to orchestrate Pytorch code execution throughout its lifecycle in less than 3 months.
· Rewrote a critical Ruby on Rails application using Spring Boot, Spring Data, ReactJS, and Kubernetes, maintaining existing
features and integrating new functionalities.
· Enhanced system performance by simplifying functionality and designing a robust SQL-based database schema, resulting in 50%
faster page loads and improved user experience. Developed test cases using Katalon and Junit, with coverage over 90%.
•Texas Instruments, Software Developer Intern |Python Automation, Analytics Jan 2022 - June 2022
· Proactively implemented Google Analytics to track user engagement and application usage, enabling data-driven prioritization of
development tasks. Provided actionable insights for management, driving more informed decision-making and strategic planning.
· Developed and standardized Python libraries for embedded and validation teams, integrating APIs from Atlassian, Klocwork, and
Qmetry. Automated design specifications in alignment with ASPICE Level X processes, ensuring rigorous compliance with hard-
ware safety standards across the development lifecycle.
•Triniti Software Labs, Machine Learning Intern |Time Series May 2019 - June 2019
· Led the development and deployment of advanced Time Series forecasting models, including ARIMA, SARIMA, and LSTM neural
networks, which resulted in a 20% improvement in sales prediction accuracy for client organizations. This improvement directly
contributed to better inventory management and demand forecasting.
· Developed and fine-tuned LSTM models using TensorFlow and Keras, achieving 88% accuracy in sales predictions.
PROJECTS
• Multimodal MNIST Classifier (Pytorch, CNN, LSTMs) (repo) - Developed a multimodal deep learning model achieving 99% accu-
racy in predicting handwritten digits from both image and audio leveraging CNNs and LSTMs.
• Movie Recommendation with LightGCN (Pytorch Geometric)(repo) - Built a movie recommendation model with Graph Neural
Network, LightGCN architecture utilizing the MovieLens Dataset. Achieved test recall at 20 of 11% and test precision at 20 of 5%.
• Term Deposit Subscription Prediction (repo) - Analyzed subscription data for term deposits using Exploratory Data Analysis•
Developed SVM and Logistic Regression models with Scikit-learn, and Neural Networks using Keras, including grid-search tuning.

Note: i would need sponsorship. And i am eligible to work in the usa. I am a male who is asian and do not have a disability.
'''

# %%
from bs4 import BeautifulSoup

def parse_html_to_dict(file_path):
    # Read the HTML file
    with open(file_path, 'r', encoding='utf-8') as file:
        soup = BeautifulSoup(file, 'html.parser')
    
    # Initialize the dictionary and counters for each tag
    result_dict = {}
    input_count = 0
    select_count = 0
    textarea_count = 0
    btn_count = 0

    # Helper function to sanitize elements
    def sanitize_element(element):
        allowed_attrs = ['class', 'id', 'aria-describedby','aria-label','aria-haspopup','aria-required']
        sanitized = {attr: element.get(attr) for attr in allowed_attrs if element.has_attr(attr)}
        return sanitized

    # Process input tags
    for input_tag in soup.find_all('input'):
        input_count += 1
        key = f"input_{input_count}"
        result_dict[key] = sanitize_element(input_tag)
        result_dict[key]["key"]=key

    # Process select tags
    for select_tag in soup.find_all('select'):
        select_count += 1
        key = f"select_{select_count}"
        result_dict[key] = sanitize_element(select_tag)
        result_dict[key]["key"]=key

    # Process textarea tags
    for textarea_tag in soup.find_all('textarea'):
        textarea_count += 1
        key = f"textarea_{textarea_count}"
        result_dict[key] = sanitize_element(textarea_tag)
        result_dict[key]["key"]=key
    
    for btn_tag in soup.find_all('button'):
        btn_count += 1
        key = f"textarea_{textarea_count}"
        result_dict[key] = sanitize_element(textarea_tag)
        result_dict[key]["key"]=key

    return result_dict

# Usage example
result = parse_html_to_dict("./eightfoldai.html")
print(result)
# Out:
# {'input_1': {'key': 'input_1'}, 'input_2': {'class': ['input-module_input-medium__fG9TN', 'input-module_input-stretch__u8aMG', 'input-module_left-icon__qeVKP', 'input-module_clear-not-visible__Uo7Aj'], 'id': 'Contact_Information_email', 'aria-required': 'true', 'key': 'input_2'}, 'input_3': {'class': ['input-module_input-medium__fG9TN', 'input-module_input-stretch__u8aMG', 'input-module_left-icon__qeVKP', 'input-module_clear-not-visible__Uo7Aj'], 'id': 'Contact_Information_firstname', 'aria-required': 'true', 'key': 'input_3'}, 'input_4': {'class': ['input-module_input-medium__fG9TN', 'input-module_input-stretch__u8aMG', 'input-module_left-icon__qeVKP', 'input-module_clear-not-visible__Uo7Aj'], 'id': 'Contact_Information_lastname', 'aria-required': 'true', 'key': 'input_4'}, 'input_5': {'class': ['select-module_select-input__bO0s9', 'input-module_input-medium__fG9TN', 'input-module_with-icon-button__xD2IE', 'input-module_input-stretch__u8aMG', 'input-module_right-icon__cF8xj', 'input
# ...

# %%
from pprint import pprint
pprint(result)
# Out:
# {'input_1': {'key': 'input_1'},
#  'input_10': {'aria-label': 'No, Are you currently eligible to work within the '
#                             'United States?',
#               'id': 'US_Work_Eligibility_us_work_eligibility-No',
#               'key': 'input_10'},
#  'input_11': {'aria-label': 'Male, Gender',
#               'id': 'US_Equal_Opportunity_Employment_Information__Completion_is_Voluntary__gender-male',
#               'key': 'input_11'},
#  'input_12': {'aria-label': 'Female, Gender',
#               'id': 'US_Equal_Opportunity_Employment_Information__Completion_is_Voluntary__gender-female',
#               'key': 'input_12'},
#  'input_13': {'aria-label': 'Decline to Self Identify, Gender',
#               'id': 'US_Equal_Opportunity_Employment_Information__Completion_is_Voluntary__gender-decline-to-self-identify',
#               'key': 'input_13'},
#  'input_14': {'aria-label': 'Hispanic or Latino, What is your race/ethnicity?',
# ...

# %%
prompt = prompt_template.invoke({"text": resume,"input_fields": result})
res = structured_llm.invoke(prompt)

# %%
import asyncio
# Define the async function to process a single result
async def process_item(resume, item):
    prompt = prompt_template.invoke({"text": resume, "input_fields": item})
    result = await asyncio.to_thread(structured_llm.invoke, prompt)  # Offload to thread
    return result

# Main function to split the result list and process it in parallel
async def run_in_parallel(resume, result):
    # Split the result list into 4 parts
    chunk_size = len(result) // 4
    chunks = [result[i:i + chunk_size] for i in range(0, len(result), chunk_size)]

    # Handle edge case where result length is not divisible by 4
    if len(result) % 4 != 0:
        chunks[-1].extend(result[len(chunks) * chunk_size:])

    # Create async tasks for each item in all chunks
    tasks = [process_item(resume, chunk) for chunk in chunks]

    # Run all tasks concurrently
    results = await asyncio.gather(*tasks)
    flattened_results = [item for chunk_results in results for item in chunk_results]
    return flattened_results

# %%
results = asyncio.run(run_in_parallel(resume, result))
for i, res in enumerate(results, start=1):
    print(f"Result {i}: {res}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 results = asyncio.run(run_in_parallel(resume, result))
#       2 for i, res in enumerate(results, start=1):
#       3     print(f"Result {i}: {res}")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/runners.py:190, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)
#     186     asyncio.run(main())
#     187 """
#     188 if events._get_running_loop() is not None:
#     189     # fail fast with short traceback
# --> 190     raise RuntimeError(
#     191         "asyncio.run() cannot be called from a running event loop")
#     193 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     194     return runner.run(main)
#
# ...

# %%
from langchain_core.runnables import RunnableParallel
ch1 = prompt_template | structured_llm
ch2 = prompt_template | structured_llm
rchain = RunnableParallel(ch1=ch1,ch2=ch2)
rchain.inv

# %%
for r in res.tags:
    print(r,end="\n")
# Out:
# is_relevant='yes' input_type='text' key='input_2' text_value='vineet.gandham@tamu.edu'
# is_relevant='yes' input_type='text' key='input_3' text_value='Vineet'
# is_relevant='yes' input_type='text' key='input_4' text_value='Gandham'
# is_relevant='yes' input_type='dropdown' key='input_5' text_value=None
# is_relevant='yes' input_type='text' key='input_6' text_value='(979)-344-3541'
# is_relevant='yes' input_type='dropdown' key='input_7' text_value=None
# is_relevant='yes' input_type='text' key='input_8' text_value=None
# is_relevant='yes' input_type='radiobutton' key='input_9' text_value=None
# is_relevant='no' input_type='radiobutton' key='input_10' text_value=None
# is_relevant='yes' input_type='radiobutton' key='input_11' text_value=None
# is_relevant='no' input_type='radiobutton' key='input_12' text_value=None
# is_relevant='no' input_type='radiobutton' key='input_13' text_value=None
# is_relevant='no' input_type='radiobutton' key='input_14' text_value=None
# ...

# %%
from bs4 import BeautifulSoup, Tag
from difflib import HtmlDiff

class HTMLHandler:
    """Handles operations on HTML using BeautifulSoup."""

    allowed_attrs = ['class', 'id', 'aria-describedby', 'aria-label', 'aria-haspopup', 'aria-required', 'data-automation-id',"autocomplete","name","type","value"]

    def __init__(self, html: str):
        self.soup = BeautifulSoup(html, "html.parser")
    
    def tags_to_list(self):
        '''
        Sample output:
        [
            {
                'key': 'input_1',
                'aria-label': 'Male, Gender',
                'id': 'gender-male',
                'idx': 0
            },
            {
                'key': 'select_1',
                'aria-label': 'Select your country',
                'id': 'country-selector',..
            },
            ...
        ]
        '''
        # Initialize the result list and counters for each tag type
        result_list = []
        input_count = 0
        select_count = 0
        textarea_count = 0
        btn_count = 0

        # Helper function to sanitize elements
        def sanitize_element(element):
            sanitized = {attr: element.get(attr) for attr in HTMLHandler.allowed_attrs if element.has_attr(attr)}
            return sanitized

        idx = 0

        # Find all desired tags in the order they appear in the DOM
        for tag in self.soup.find_all(['input', 'select', 'textarea', 'button']):
            tag_dict = sanitize_element(tag)

            if tag.name == 'input':
                input_count += 1
                key = f"input_{input_count}"
                tag_type='input'
            elif tag.name == 'select':
                select_count += 1
                key = f"select_{select_count}"
                tag_type='select'
            elif tag.name == 'textarea':
                textarea_count += 1
                key = f"textarea_{textarea_count}"
                tag_type='textarea'
            elif tag.name == 'button':
                btn_count += 1
                key = f"button_{btn_count}"
                tag_type='button'
            else:
                continue  # Skip unsupported tags

             # Find nearest text above
            text_above = []
            for prev in tag.find_all_previous(string=True, limit=3):
                stripped = prev.strip()
                if stripped:
                    text_above.append(stripped[:min(120,len(stripped))])
            text_above.reverse()  # Reverse to maintain top-to-bottom order

            # Find nearest text below
            text_below = []
            for next_ in tag.find_all_next(string=True, limit=3):
                stripped = next_.strip()
                if stripped:
                    text_below.append(stripped[:min(120,len(stripped))])

            tag_dict["text_above_htmltag"] = text_above
            tag_dict["text_below_htmltag"] = text_below
            tag_dict["key"] = key
            tag_dict["idx"] = idx
            tag_dict["tag_type"] = tag_type
            idx += 1
            result_list.append(tag_dict)

        return result_list


    def get_input_elements(self):
        """
        Extract all input elements from the HTML.
        :return: List of input elements as dictionaries (attributes only).
        """
        inputs = self.soup.find_all("input")
        return [dict(inp.attrs) for inp in inputs]

    def compare_html(self, html1: str, html2: str):
        """
        Compare two HTML DOMs and return the differences.
        :param html1: First HTML content.
        :param html2: Second HTML content.
        :return: HTML string showing the differences.
        """
        diff_tool = HtmlDiff()
        diff_html = diff_tool.make_file(html1.splitlines(), html2.splitlines())
        return diff_html
    
    def get_element_with_text(self, search_text: str):
        """
        Get the element containing a given text and its allowed attributes.
        :param search_text: Text to search for.
        :return: Dictionary of allowed attributes and related information, or None if not found.
        """
        element = self.soup.find(string=lambda text: search_text.strip()==text.strip()  if text else False)
        if not element:
            return None

        # Ensure the element is a Tag, not a NavigableString
        if isinstance(element, str):
            element = element.parent

        result = {}

        # Get allowed attributes
        for attr in self.allowed_attrs:
            if element.has_attr(attr):
                attr_value = element[attr]
                # Convert to list if it's a space-separated string for class
                if attr == 'class' and isinstance(attr_value, str):
                    result[attr] = attr_value.split()
                else:
                    result[attr] = attr_value

        # Add additional fields
        result.update({
            'key': f"element_{element.sourceline if hasattr(element, 'sourceline') else 0}",  # Example key generation
            'idx': element.sourceline if hasattr(element, 'sourceline') else 0,
            'tag_type': element.name,
            'is_relevant_or_required': 'yes' if element.get('aria-required') == 'true' else 'no',
            'text_value': search_text,
            'is_filled': 'yes' if element.get('value') else 'no',
            'general_input_group': 'dropdown' if element.get('aria-haspopup') == 'true' else '',
            'description': f"Element containing the text: {search_text}"
        })

        return result

    def get_parent_of_text(self, search_text: str):
        """
        Get the parent element and its attributes of the first occurrence of a given text.
        :param search_text: Text to search for.
        :return: Dictionary of allowed attributes and related information, or None if not found.
        """
        element = self.soup.find(string=lambda text: search_text.strip()==text.strip() if text else False)
        if not element or not element.parent:
            return None

        parent = element.parent
        result = {}

        # Get allowed attributes
        for attr in self.allowed_attrs:
            if parent.has_attr(attr):
                attr_value = parent[attr]
                # Convert to list if it's a space-separated string for class
                if attr == 'class' and isinstance(attr_value, str):
                    result[attr] = attr_value.split()
                else:
                    result[attr] = attr_value

        # Get text above the tag (previous siblings' text)
        text_above = []
        for sibling in parent.find_previous_siblings():
            if sibling.string and sibling.string.strip():
                text_above.append(sibling.string.strip())
        result['text_above_htmltag'] = list(reversed(text_above))

        # Get text below the tag (next siblings' text)
        text_below = []
        for sibling in parent.find_next_siblings():
            if sibling.string and sibling.string.strip():
                text_below.append(sibling.string.strip())
        result['text_below_htmltag'] = text_below

        # Add additional fields
        result.update({
            'key': f"input_{len(result.get('text_above_htmltag', []))}", # Example key generation
            'idx': parent.sourceline if hasattr(parent, 'sourceline') else 0,
            'tag_type': parent.name,
            'is_relevant_or_required': 'yes' if parent.get('aria-required') == 'true' else 'no',
            'text_value': search_text,
            'is_filled': 'yes' if parent.get('value') else 'no',
            'general_input_group': 'dropdown' if parent.get('aria-haspopup') == 'true' else '',
            'description': f"A {parent.name} element for {search_text}"
        })

        return result

    def extract_text_nodes(self):
        return [text.strip() for text in self.soup.stripped_strings]
        
    def print_lines(self):
        old_lines = set(self.get_lines_of_text())
        for a in old_lines:
            print(a)

    @classmethod
    def compare_html(cls, old_handler, new_handler):
        """
        Compares two HTMLHandler objects and finds lines of text
        that are new in the new_handler compared to old_handler.
        """
        old_lines = set(old_handler.extract_text_nodes())
        new_lines = set(new_handler.extract_text_nodes())

        new_in_new_html = new_lines - old_lines
        return new_in_new_html

# %%
def read_html_file(file_path):
    """
    Reads an HTML file and returns its content as a string.
    :param file_path: The path to the HTML file.
    :return: The content of the file as a string.
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            html_content = file.read()
        return html_content
    except FileNotFoundError:
        print(f"Error: The file at {file_path} was not found.")
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

# Example usage
file_path = 'options.html'
html_content = read_html_file(file_path)
if html_content:
    print(html_content)
htmlo = HTMLHandler(html_content)
# Out:
# <html lang="en" dir="ltr">
#   <head>
#     <meta
#       http-equiv="origin-trial"
#       content="3NNj0GXVktLOmVKwWUDendk4Vq2qgMVDBDX+Sni48ATJl9JBj+zF+9W2HGB3pvt6qowOihTbQgTeBm9SKbdTwYAAABfeyJvcmlnaW4iOiJodHRwczovL3JlY2FwdGNoYS5uZXQ6NDQzIiwiZmVhdHVyZSI6IlRwY2QiLCJleHBpcnkiOjE3MzUzNDM5OTksImlzVGhpcmRQYXJ0eSI6dHJ1ZX0="
#     />
#     <meta
#       http-equiv="origin-trial"
#       content=""
#     />
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width,initial-scale=1" />
#     <link
#       rel="preload"
#       as="image"
#       href="https://s4-recruiting.cdn.greenhouse.io/external_greenhouse_job_boards/logos/400/377/100/original/Figma-icon-sm.png?1726611002"
# ...

# %%
file_path = 'woptions.html'
html_content = read_html_file(file_path)
if html_content:
    print(html_content)
htmlwo = HTMLHandler(html_content)
# Out:
# <html lang="en" dir="ltr">
#   <head>
#     <meta
#       http-equiv="origin-trial"
#       content="3NNj0GXVktLOmVKwWUDendk4Vq2qgMVDBDX+Sni48ATJl9JBj+zF+9W2HGB3pvt6qowOihTbQgTeBm9SKbdTwYAAABfeyJvcmlnaW4iOiJodHRwczovL3JlY2FwdGNoYS5uZXQ6NDQzIiwiZmVhdHVyZSI6IlRwY2QiLCJleHBpcnkiOjE3MzUzNDM5OTksImlzVGhpcmRQYXJ0eSI6dHJ1ZX0="
#     />
#     <meta
#       http-equiv="origin-trial"
#       content=""
#     />
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width,initial-scale=1" />
#     <link
#       rel="preload"
#       as="image"
#       href="https://s4-recruiting.cdn.greenhouse.io/external_greenhouse_job_boards/logos/400/377/100/original/Figma-icon-sm.png?1726611002"
# ...

# %%
htmlwo.extract_text_nodes()
# Out:
# ['Job Application for Software Engineer - Early Career (2025) at Figma',
#  'Back to jobs',
#  'Software Engineer - Early Career (2025)',
#  'San Francisco, CA • New York, NY • United States',
#  'Apply',
#  'Figma is growing our team of passionate people on a mission to\n                make design accessible to all.',
#  'Born on the Web',
#  ', Figma helps entire product teams',
#  'brainstorm',
#  ', design and build better products — from start to finish.\n                Whether it’s consolidating tools, simplifying workflows, or\n                collaborating across teams and time zones, Figma makes the\n                design process faster, more efficient, and fun while keeping\n                everyone on the same page. From great products to long-lasting\n                companies, we believe that nothing great is made\n                alone—come',
#  'make',
#  'with us!',
# ...

# %%
HTMLHandler.compare_html(htmlwo,htmlo)
# Out:
# {'8 results available.',
#  'Fall 2025',
#  'Fall 2026',
#  'Fall 2027',
#  'I am not currently enrolled',
#  'Other',
#  'Spring 2025',
#  'Spring 2025, 1 of 8.',
#  'Spring 2026',
#  'Spring 2027',
#  'Use Up and Down to choose options, press Enter to\n                          select the currently focused option, press Escape to\n                          exit the menu, press Tab to select the option and exit\n                          the menu.'}
